# %% [markdown]
# # Image reduction framework
# <br>
# This notebook is a framework for utilizing WDP for image reduction. First step is to find the wdp package on your system.

# %%
import sys

wdpipe_location = "/home/jpsrocha/MEGA/Projects/installing_wdpipe/WildDuckPipe"
wfc3_photometry_location = "/home/jpsrocha/MEGA/Projects/installing_wdpipe"


sys.path.append(wdpipe_location)
sys.path.append(wfc3_photometry_location)

# %%
# Standard lib import
from os.path import exists
import os

# Third part import
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Local import
import wdpipe as wdp

# Configuring Matplotlib
plt.style.use("seaborn-whitegrid")
plt.rcParams["figure.dpi"] = 100
plt.rcParams["figure.figsize"] = (15, 10)
# Out:
# /tmp/ipykernel_339640/1104108537.py:14: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-whitegrid")

# %% [markdown]
# Now let's set the data folder.

# %%
os.getcwd()
# Out:
# '/home/jpsrocha/MEGA/Projects/installing_wdpipe'

# %%
# Data location on my system
data_folder = "/home/jpsrocha/Documents/Data/OPD/18out30/"

# %% [markdown]
# # Applying initial reduction
# <br>
# Running the initial reduction script. The initial script function will:
#
# 1. Organize files into folders
# 2. Generate master Bias and Flat
# 3. Apply master calibration files on the science images
#
# <br>
#
# All the resulting files will be on a folder with the same name of the original prepended with "r_". By default the results will be saved on the same folder, but optionally you can pass another output path.
#
# > **Important** : This script assumes that all the data is following the conventions used on the mission OI2018B-011.

# %%
from wdpipe.pre_processing.processes import initial_reduction
initial_reduction(data_folder)
# Out:
# Starting to process folder /home/jpsrocha/Documents/Data/OPD/18out30/
#
# Getting log for /home/jpsrocha/Documents/Data/OPD/18out30 ...
#
# Summary
# ---------------
#
# 	Total: 32 	 Calibration: 12 	 Science: 20 	 Others: 0
#
# Calibration files
# -----------------
#
# 	Bias images: 3
# 	Flat images: 9	(  B: 3  V: 3  I: 3  )
#
# Science images
# --------------
#
# 	M11: 20 (  V: 20  ) 	 Exptimes: [120]s 	 1.76 < X < 2.44
#
# Creating new folder structure for /home/jpsrocha/Documents/Data/OPD/18out30 ...
#
# Copying files to structure ...
#
# Copying bias ...
#
# Copying 3 files...
#
# /home/jpsrocha/Documents/Data/OPD/18out30/bias_0018.fits ====> /home/jpsrocha/Documents/Data/OPD/r_18out30/calibration/bias/bias_0018.fits (1 de 3)
# .Skipping /home/jpsrocha/Documents/Data/OPD/r_18out30/calibration/bias: File already exists
# /home/jpsrocha/Documents/Data/OPD/18out30/bias_0019.fits ====> /home/jpsrocha/Documents/Data/OPD/r_18out30/calibration/bias/bias_0019.fits (2 de 3)
# .Skipping /home/jpsrocha/Documents/Data/OPD/r_18out30/calibration/bias: File already exists
# /home/jpsrocha/Documents/Data/OPD/18out30/bias_0020.fits ====> /home/jpsrocha/Documents/Data/OPD/r_18out30/calibration/bias/bias_0020.fits (3 de 3)
# .Skipping /home/jpsrocha/Documents/Data/OPD/r_18out30/calibration/bias: File already exists
#
#
# Copying flats ...
#
# Copying 9 files...
#
# /home/jpsrocha/Documents/Data/OPD/18out30/flat_0021.fits ====> /home/jpsrocha/Documents/Data/OPD/r_18out30/calibration/flat/flat_0021.fits (1 de 9)
# .Skipping /home/jpsrocha/Documents/Data/OPD/r_18out30/calibration/flat: File already exists
# /home/jpsrocha/Documents/Data/OPD/18out30/flat_0022.fits ====> /home/jpsrocha/Documents/Data/OPD/r_18out30/calibration/flat/flat_0022.fits (2 de 9)
# .Skipping /home/jpsrocha/Documents/Data/OPD/r_18out30/calibration/flat: File already exists
# /home/jpsrocha/Documents/Data/OPD/18out30/flat_0023.fits ====> /home/jpsrocha/Documents/Data/OPD/r_18out30/calibration/flat/flat_0023.fits (3 de 9)
# .Skipping /home/jpsrocha/Documents/Data/OPD/r_18out30/calibration/flat: File already exists
# /home/jpsrocha/Documents/Data/OPD/18out30/flat_0042.fits ====> /home/jpsrocha/Documents/Data/OPD/r_18out30/calibration/flat/flat_0042.fits (4 de 9)
# .Skipping /home/jpsrocha/Documents/Data/OPD/r_18out30/calibration/flat: File already exists
# /home/jpsrocha/Documents/Data/OPD/18out30/flat_0043.fits ====> /home/jpsrocha/Documents/Data/OPD/r_18out30/calibration/flat/flat_0043.fits (5 de 9)
# .Skipping /home/jpsrocha/Documents/Data/OPD/r_18out30/calibration/flat: File already exists
# /home/jpsrocha/Documents/Data/OPD/18out30/flat_0044.fits ====> /home/jpsrocha/Documents/Data/OPD/r_18out30/calibration/flat/flat_0044.fits (6 de 9)
# .Skipping /home/jpsrocha/Documents/Data/OPD/r_18out30/calibration/flat: File already exists
# /home/jpsrocha/Documents/Data/OPD/18out30/flat_0063.fits ====> /home/jpsrocha/Documents/Data/OPD/r_18out30/calibration/flat/flat_0063.fits (7 de 9)
# .Skipping /home/jpsrocha/Documents/Data/OPD/r_18out30/calibration/flat: File already exists
# /home/jpsrocha/Documents/Data/OPD/18out30/flat_0064.fits ====> /home/jpsrocha/Documents/Data/OPD/r_18out30/calibration/flat/flat_0064.fits (8 de 9)
# .Skipping /home/jpsrocha/Documents/Data/OPD/r_18out30/calibration/flat: File already exists
# /home/jpsrocha/Documents/Data/OPD/18out30/flat_0065.fits ====> /home/jpsrocha/Documents/Data/OPD/r_18out30/calibration/flat/flat_0065.fits (9 de 9)
# .Skipping /home/jpsrocha/Documents/Data/OPD/r_18out30/calibration/flat: File already exists
#
#
# Copying science images ...
#
# Copying 20 files...
#
# /home/jpsrocha/Documents/Data/OPD/18out30/OI2018B-011_2018-10-30_0136.fits ====> /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0136.fits (1 de 20)
# .Skipping /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced: File already exists
# /home/jpsrocha/Documents/Data/OPD/18out30/OI2018B-011_2018-10-30_0137.fits ====> /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0137.fits (2 de 20)
# .Skipping /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced: File already exists
# /home/jpsrocha/Documents/Data/OPD/18out30/OI2018B-011_2018-10-30_0138.fits ====> /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0138.fits (3 de 20)
# .Skipping /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced: File already exists
# /home/jpsrocha/Documents/Data/OPD/18out30/OI2018B-011_2018-10-30_0139.fits ====> /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0139.fits (4 de 20)
# .Skipping /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced: File already exists
# /home/jpsrocha/Documents/Data/OPD/18out30/OI2018B-011_2018-10-30_0140.fits ====> /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0140.fits (5 de 20)
# .Skipping /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced: File already exists
# /home/jpsrocha/Documents/Data/OPD/18out30/OI2018B-011_2018-10-30_0141.fits ====> /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0141.fits (6 de 20)
# .Skipping /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced: File already exists
# /home/jpsrocha/Documents/Data/OPD/18out30/OI2018B-011_2018-10-30_0142.fits ====> /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0142.fits (7 de 20)
# .Skipping /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced: File already exists
# /home/jpsrocha/Documents/Data/OPD/18out30/OI2018B-011_2018-10-30_0143.fits ====> /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0143.fits (8 de 20)
# .Skipping /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced: File already exists
# /home/jpsrocha/Documents/Data/OPD/18out30/OI2018B-011_2018-10-30_0144.fits ====> /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0144.fits (9 de 20)
# .Skipping /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced: File already exists
# /home/jpsrocha/Documents/Data/OPD/18out30/OI2018B-011_2018-10-30_0145.fits ====> /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0145.fits (10 de 20)
# .Skipping /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced: File already exists
# /home/jpsrocha/Documents/Data/OPD/18out30/OI2018B-011_2018-10-30_0148.fits ====> /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0148.fits (11 de 20)
# .Skipping /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced: File already exists
# /home/jpsrocha/Documents/Data/OPD/18out30/OI2018B-011_2018-10-30_0149.fits ====> /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0149.fits (12 de 20)
# .Skipping /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced: File already exists
# /home/jpsrocha/Documents/Data/OPD/18out30/OI2018B-011_2018-10-30_0150.fits ====> /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0150.fits (13 de 20)
# .Skipping /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced: File already exists
# /home/jpsrocha/Documents/Data/OPD/18out30/OI2018B-011_2018-10-30_0151.fits ====> /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0151.fits (14 de 20)
# .Skipping /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced: File already exists
# /home/jpsrocha/Documents/Data/OPD/18out30/OI2018B-011_2018-10-30_0152.fits ====> /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0152.fits (15 de 20)
# .Skipping /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced: File already exists
# /home/jpsrocha/Documents/Data/OPD/18out30/OI2018B-011_2018-10-30_0153.fits ====> /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0153.fits (16 de 20)
# .Skipping /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced: File already exists
# /home/jpsrocha/Documents/Data/OPD/18out30/OI2018B-011_2018-10-30_0154.fits ====> /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0154.fits (17 de 20)
# .Skipping /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced: File already exists
# /home/jpsrocha/Documents/Data/OPD/18out30/OI2018B-011_2018-10-30_0155.fits ====> /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0155.fits (18 de 20)
# .Skipping /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced: File already exists
# /home/jpsrocha/Documents/Data/OPD/18out30/OI2018B-011_2018-10-30_0156.fits ====> /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0156.fits (19 de 20)
# .Skipping /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced: File already exists
# /home/jpsrocha/Documents/Data/OPD/18out30/OI2018B-011_2018-10-30_0157.fits ====> /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0157.fits (20 de 20)
# .Skipping /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced: File already exists
#
#
# Organizing flat images ...
# WARNING: FITSFixedWarning: EPOCH = '2000.0 ' / Epoca
# a floating-point value was expected. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: EPOCH = '2000.0 ' / Epoca
# a floating-point value was expected.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58421.848485 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58421.848485 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58421.848410 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58421.848410 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58421.848559 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58421.848559 from DATE-OBS'.
# Moving 3 files...
#
# flat_0021.fits ====> B/flat_0021.fits (1 de 3)
# flat_0022.fits ====> B/flat_0022.fits (2 de 3)
# flat_0023.fits ====> B/flat_0023.fits (3 de 3)
#
#
# Moving 3 files...
#
# flat_0042.fits ====> V/flat_0042.fits (1 de 3)
# flat_0043.fits ====> V/flat_0043.fits (2 de 3)
# flat_0044.fits ====> V/flat_0044.fits (3 de 3)
#
#
# Moving 3 files...
#
# flat_0063.fits ====> I/flat_0063.fits (1 de 3)
# flat_0064.fits ====> I/flat_0064.fits (2 de 3)
# flat_0065.fits ====> I/flat_0065.fits (3 de 3)
#
#
# Moving metadata ...
#
# Copying 2 files...
#
# /home/jpsrocha/Documents/Data/OPD/18out30_night.log ====> /home/jpsrocha/Documents/Data/OPD/r_18out30/18out30_night.log (1 de 2)
# .Skipping /home/jpsrocha/Documents/Data/OPD/r_18out30: File already exists
# /home/jpsrocha/Documents/Data/OPD/18out30_night.summary ====> /home/jpsrocha/Documents/Data/OPD/r_18out30/18out30_night.summary (2 de 2)
# .Skipping /home/jpsrocha/Documents/Data/OPD/r_18out30: File already exists
#
#
#
# Processing bias images.
#
# .Skipping bias overscan correction on: index [0] - BIASSEC keyword not found
# WARNING: FITSFixedWarning: EPOCH = '2000.0 ' / Epoca
# a floating-point value was expected. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: EPOCH = '2000.0 ' / Epoca
# a floating-point value was expected.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58421.848485 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58421.848485 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58421.859764 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58421.859764 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58421.860953 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58421.860953 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58421.861259 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58421.861259 from DATE-OBS'.
# Processed master bias:  /home/jpsrocha/Documents/Data/OPD/r_18out30/master/master_bias.fits
#
# Processing flat images.
#
# .Skipping flat overscan correction on: index [0] - BIASSEC keyword not found
# /home/jpsrocha/mambaforge/envs/wdpipe/lib/python3.10/site-packages/numpy/core/fromnumeric.py:771: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# WARNING: FITSFixedWarning: EPOCH = '2000.0 ' / Epoca
# a floating-point value was expected. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: EPOCH = '2000.0 ' / Epoca
# a floating-point value was expected.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58421.848485 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58421.848485 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58421.868879 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58421.868879 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58421.870099 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58421.870099 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58421.869977 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58421.869977 from DATE-OBS'.
# Processed master flat on B :  /home/jpsrocha/Documents/Data/OPD/r_18out30/master/master_flat_B.fits
# .Skipping flat overscan correction on: index [0] - BIASSEC keyword not found
# /home/jpsrocha/mambaforge/envs/wdpipe/lib/python3.10/site-packages/numpy/core/fromnumeric.py:771: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# WARNING: FITSFixedWarning: EPOCH = '2000.0 ' / Epoca
# a floating-point value was expected. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: EPOCH = '2000.0 ' / Epoca
# a floating-point value was expected.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58421.848485 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58421.848485 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58421.874879 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58421.874879 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58421.873920 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58421.873920 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58421.875001 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58421.875001 from DATE-OBS'.
# Processed master flat on V :  /home/jpsrocha/Documents/Data/OPD/r_18out30/master/master_flat_V.fits
# .Skipping flat overscan correction on: index [0] - BIASSEC keyword not found
# /home/jpsrocha/mambaforge/envs/wdpipe/lib/python3.10/site-packages/numpy/core/fromnumeric.py:771: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# WARNING: FITSFixedWarning: EPOCH = '2000.0 ' / Epoca
# a floating-point value was expected. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: EPOCH = '2000.0 ' / Epoca
# a floating-point value was expected.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58421.957394 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58421.957394 from DATE-OBS'.
# Processed master flat on I :  /home/jpsrocha/Documents/Data/OPD/r_18out30/master/master_flat_I.fits
#
# Processing 20 science images.
#
# Skipping overscan correction on: /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0157.fits[0] - BIASSEC keyword not found
# Skipping overscan correction on: /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0153.fits[0] - BIASSEC keyword not found
# Skipping overscan correction on: /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0149.fits[0] - BIASSEC keyword not found
# Skipping overscan correction on: /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0144.fits[0] - BIASSEC keyword not found
# Skipping overscan correction on: /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0142.fits[0] - BIASSEC keyword not found
# Skipping overscan correction on: /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0155.fits[0] - BIASSEC keyword not found
# Skipping overscan correction on: /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0136.fits[0] - BIASSEC keyword not found
# Skipping overscan correction on: /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0139.fits[0] - BIASSEC keyword not found
# Skipping overscan correction on: /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0138.fits[0] - BIASSEC keyword not found
# Skipping overscan correction on: /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0148.fits[0] - BIASSEC keyword not found
# Skipping overscan correction on: /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0141.fits[0] - BIASSEC keyword not found
# Skipping overscan correction on: /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0140.fits[0] - BIASSEC keyword not found
# Skipping overscan correction on: /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0151.fits[0] - BIASSEC keyword not found
# Skipping overscan correction on: /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0137.fits[0] - BIASSEC keyword not found
# Skipping overscan correction on: /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0154.fits[0] - BIASSEC keyword not found
# Skipping overscan correction on: /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0156.fits[0] - BIASSEC keyword not found
# Skipping overscan correction on: /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0150.fits[0] - BIASSEC keyword not found
# Skipping overscan correction on: /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0152.fits[0] - BIASSEC keyword not found
# Skipping overscan correction on: /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0143.fits[0] - BIASSEC keyword not found
# Skipping overscan correction on: /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0145.fits[0] - BIASSEC keyword not found
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58421.958854 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58421.958854 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58421.960313 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58421.960313 from DATE-OBS'.
# Processed image: /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0136.fits
# Processed image: /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0137.fits
# Processed image: /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/OI2018B-011_2018-10-30_0138.fits
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58421
# OI2021A-023_2020-05-03_0876.fits ====> 30/OI2021A-023_2020-05-03_0876.fits (488 de 495)
# OI2021A-023_2020-05-03_0877.fits ====> 30/OI2021A-023_2020-05-03_0877.fits (489 de 495)
# OI2021A-023_2020-05-03_0878.fits ====> 30/OI2021A-023_2020-05-03_0878.fits (490 de 495)
# OI2021A-023_2020-05-03_0879.fits ====> 30/OI2021A-023_2020-05-03_0879.fits (491 de 495)
# OI2021A-023_2020-05-03_0880.fits ====> 30/OI2021A-023_2020-05-03_0880.fits (492 de 495)
# OI2021A-023_2020-05-03_0881.fits ====> 30/OI2021A-023_2020-05-03_0881.fits (493 de 495)
# OI2021A-023_2020-05-03_0882.fits ====> 30/OI2021A-023_2020-05-03_0882.fits (494 de 495)
# OI2021A-023_2020-05-03_0883.fits ====> 30/OI2021A-023_2020-05-03_0883.fits (495 de 495)
#
#
#
# Cleaning up calibration files.
#
# Processing finished.

# %% [markdown]
# # Aligning images
# <br>
# Now let's align the images with the first one. It can be done using a simple command from WDP since it is a rich field.

# %%
from wdpipe.pre_processing.alignment import align_all_images

# For alignment it's necessary to pass a folder containing the group of images to reduce
# Since the first step already organizes the images into object, filter and exposure time
# one can simply pass one of those folders.

object_folder = "/home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/M11/V/120"

align_all_images(object_folder)
# Out:
# Aligning 20 images with file OI2018B-011_2018-10-30_0136.fits in folder /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/M11/V/120.
#
# Aligning: OI2018B-011_2018-10-30_0136.fits (1 of 20).
# WARNING: VerifyWarning: Keyword name 'ALIGNED-TO' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING:astropy:VerifyWarning: Keyword name 'ALIGNED-TO' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created.
# Aligning: OI2018B-011_2018-10-30_0137.fits (2 of 20).
# Aligning: OI2018B-011_2018-10-30_0138.fits (3 of 20).
# Aligning: OI2018B-011_2018-10-30_0139.fits (4 of 20).
# Aligning: OI2018B-011_2018-10-30_0140.fits (5 of 20).
# Aligning: OI2018B-011_2018-10-30_0141.fits (6 of 20).
# Aligning: OI2018B-011_2018-10-30_0142.fits (7 of 20).
# Aligning: OI2018B-011_2018-10-30_0143.fits (8 of 20).
# Aligning: OI2018B-011_2018-10-30_0144.fits (9 of 20).
# Aligning: OI2018B-011_2018-10-30_0145.fits (10 of 20).
# Aligning: OI2018B-011_2018-10-30_0148.fits (11 of 20).
# Aligning: OI2018B-011_2018-10-30_0149.fits (12 of 20).
# Aligning: OI2018B-011_2018-10-30_0150.fits (13 of 20).
# Aligning: OI2018B-011_2018-10-30_0151.fits (14 of 20).
# Aligning: OI2018B-011_2018-10-30_0152.fits (15 of 20).
# Aligning: OI2018B-011_2018-10-30_0153.fits (16 of 20).
# Aligning: OI2018B-011_2018-10-30_0154.fits (17 of 20).
# Aligning: OI2018B-011_2018-10-30_0155.fits (18 of 20).
# Aligning: OI2018B-011_2018-10-30_0156.fits (19 of 20).
# Aligning: OI2018B-011_2018-10-30_0157.fits (20 of 20).
#
#  Finished alignment of /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/M11/V/120 images.

# %%
align_all_images?
# Out:
# Signature:
# align_all_images(
#     images_folder,
#     ref_file=None,
#     max_control_points=50,
#     min_area=5,
# )
# Docstring:
# Align all FITS stellar images to reference file. If reference file is set
# to None it uses the first image in the folder.
#
# # Wraps align_with function.
#
# Parameters
# ----------
#     images_folder : str
#         Path to folder with images to align.
#     ref_file : str
#         Path to FITS with reference field. Default is None, so it takes
#         the first file of the folder.
#
# Returns
# -------
#     None.
#
# File transformation
# -------------------
#     Re-write FITS files with aligned version.
# File:      ~/MEGA/Projects/installing_wdpipe/WildDuckPipe/wdpipe/pre_processing/alignment.py
# Type:      function

# %% [markdown]
# # Inspecting images
#
# Now that all images are aligned i can use the script for getting parameters based on sky patches.
#
# To use it i need to create a file with the central pixel of some stars and some patches of clear sky.
#
# The process is the following:
#
# 1. Create a file like:
#
# kind,x,y
#
# sky,100,200
#
# star,150,300
#
# > OBS:: The example has only one of each but you should add as many as you judge necessary.
#
# 2. Use the inspect.py script on the inspection module or the inspect function.
#
# `$python inspect images_folder ref_file out_name`

# %%
# Put the paths here

from wdpipe.inspection.inspect import inspect

parameters_outfile = "parameters_18out30_120.csv"
ref_positions_file = "ref_positions_18out30_120.csv"

if not exists(parameters_outfile):
    parameters = inspect(object_folder, ref_positions_file, parameters_outfile)
else:
    parameters = pd.read_csv(parameters_outfile)
# Out:
# Getting parameters for file: a_OI2018B-011_2018-10-30_0136.fits (1 of 20)
# Getting parameters for file: a_OI2018B-011_2018-10-30_0137.fits (2 of 20)
# Getting parameters for file: a_OI2018B-011_2018-10-30_0138.fits (3 of 20)
# Getting parameters for file: a_OI2018B-011_2018-10-30_0139.fits (4 of 20)
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# WARNING:astropy:The fit may be unsuccessful; check fit_info['message'] for more information.
# Getting parameters for file: a_OI2018B-011_2018-10-30_0140.fits (5 of 20)
# Getting parameters for file: a_OI2018B-011_2018-10-30_0141.fits (6 of 20)
# Getting parameters for file: a_OI2018B-011_2018-10-30_0142.fits (7 of 20)
# Getting parameters for file: a_OI2018B-011_2018-10-30_0143.fits (8 of 20)
# Getting parameters for file: a_OI2018B-011_2018-10-30_0144.fits (9 of 20)
# Getting parameters for file: a_OI2018B-011_2018-10-30_0145.fits (10 of 20)
# Getting parameters for file: a_OI2018B-011_2018-10-30_0148.fits (11 of 20)
# Getting parameters for file: a_OI2018B-011_2018-10-30_0149.fits (12 of 20)
# Getting parameters for file: a_OI2018B-011_2018-10-30_0150.fits (13 of 20)
# Getting parameters for file: a_OI2018B-011_2018-10-30_0151.fits (14 of 20)
# Getting parameters for file: a_OI2018B-011_2018-10-30_0152.fits (15 of 20)
# Getting parameters for file: a_OI2018B-011_2018-10-30_0153.fits (16 of 20)
# Getting parameters for file: a_OI2018B-011_2018-10-30_0154.fits (17 of 20)
# Getting parameters for file: a_OI2018B-011_2018-10-30_0155.fits (18 of 20)
# Getting parameters for file: a_OI2018B-011_2018-10-30_0156.fits (19 of 20)
# Getting parameters for file: a_OI2018B-011_2018-10-30_0157.fits (20 of 20)
#
# Finished getting parameters!

# %% [markdown]
# # Filtering
# <br>
#
# Let's now use a simple trick to filter the data. Let's remove some images based on the distribution of min and max pixel over all images. This can be facilitated by the min_max_filtering function.

# %%
# Let's use the min_max_filtering function

from wdpipe.inspection.filtering import min_max_filtering


final_selection = min_max_filtering(parameters)

final_selection.file.to_csv("final_selection_18out30_120.csv")
# Out:
# Set value to cut from to the right of the min distribution:  0
# Set value to cut to from the left of the max distribution:  59000
# This cut filters: 4 Images (20.00% of the total data)
# Confirm selection? [y/n] y

# %%
# Let's now move the files filtered to a folder.

from wdpipe.pre_processing.file_organization import move_lacking_fits

move_lacking_fits(object_folder, final_selection.file, "problematic")
# Out:
# Moving 4 FITS files from 20
# Moving 4 files...
#
# a_OI2018B-011_2018-10-30_0136.fits ====> problematic/a_OI2018B-011_2018-10-30_0136.fits (1 de 4)
# a_OI2018B-011_2018-10-30_0137.fits ====> problematic/a_OI2018B-011_2018-10-30_0137.fits (2 de 4)
# a_OI2018B-011_2018-10-30_0141.fits ====> problematic/a_OI2018B-011_2018-10-30_0141.fits (3 de 4)
# a_OI2018B-011_2018-10-30_0145.fits ====> problematic/a_OI2018B-011_2018-10-30_0145.fits (4 de 4)

# %%
# If decide to skip the filtering part, use the command bellow
# final_selection = parameters

# %% [markdown]
# # Creating batches

# %%
from wdpipe.pre_processing.combination import generate_combination_bins

generate_combination_bins(object_folder, final_selection, 120, 3, 1)
# Out:
# Group sizes: [16]
# [[2, 3, 4],
#  [4, 6, 7],
#  [7, 8, 10],
#  [10, 11, 12],
#  [12, 13, 14],
#  [14, 15, 16],
#  [16, 17, 18]]

# %%
generate_combination_bins?
# Out:
# Signature:
# generate_combination_bins(
#     data_folder,
#     final_selection,
#     exptime,
#     bin_size,
#     overlap,
#     n=5,
# )
# Docstring:
# Calculate combination bins and generate a file for each combination bin in
# a given folder.
#
# The files will be on a folder called `bins` inside the `data_folder`.
#
# Parameters
# ----------
#     data_folder: str
#         Path to the data
#
#     final_selection: pd.DataFrame
#         Parameters dataframe of the final data selection.
#
#     exptime: float
#         Exposure time in seconds.
#
#     bin_size: int
#         Desired size for the bins.
#
#     overlap: int
#         Amount of overlap between images.
#
#     n: int, default: 5
#         number of exposure times of separation in time to define an
#         observation block.
#
# File transformations
# --------------------
#     Create a folder called `bins` and fill it with one file with each
#     combination of files.
#
# Returns
# -------
#     bins: list of lists
#         Return list containing lists of filenames that represents
#         combination bin.
# File:      ~/MEGA/Projects/installing_wdpipe/WildDuckPipe/wdpipe/pre_processing/combination.py
# Type:      function

# %% [markdown]
# # Combining images

# %%
from wdpipe.pre_processing.combination import combine_batches
final_files = combine_batches(object_folder, batches_folder="bins", out_folder="final")
# Out:
# Combining batch: ['a_OI2018B-011_2018-10-30_0138.fits', 'a_OI2018B-011_2018-10-30_0139.fits', 'a_OI2018B-011_2018-10-30_0140.fits']
# Creating image: final_OI2018B-011_2018-10-30_0001 (1 de 7)
# Combining batch: ['a_OI2018B-011_2018-10-30_0140.fits', 'a_OI2018B-011_2018-10-30_0142.fits', 'a_OI2018B-011_2018-10-30_0143.fits']
# Creating image: final_OI2018B-011_2018-10-30_0002 (2 de 7)
# Combining batch: ['a_OI2018B-011_2018-10-30_0143.fits', 'a_OI2018B-011_2018-10-30_0144.fits', 'a_OI2018B-011_2018-10-30_0148.fits']
# Creating image: final_OI2018B-011_2018-10-30_0003 (3 de 7)
# Combining batch: ['a_OI2018B-011_2018-10-30_0148.fits', 'a_OI2018B-011_2018-10-30_0149.fits', 'a_OI2018B-011_2018-10-30_0150.fits']
# Creating image: final_OI2018B-011_2018-10-30_0004 (4 de 7)
# Combining batch: ['a_OI2018B-011_2018-10-30_0150.fits', 'a_OI2018B-011_2018-10-30_0151.fits', 'a_OI2018B-011_2018-10-30_0152.fits']
# Creating image: final_OI2018B-011_2018-10-30_0005 (5 de 7)
# Combining batch: ['a_OI2018B-011_2018-10-30_0152.fits', 'a_OI2018B-011_2018-10-30_0153.fits', 'a_OI2018B-011_2018-10-30_0154.fits']
# Creating image: final_OI2018B-011_2018-10-30_0006 (6 de 7)
# Combining batch: ['a_OI2018B-011_2018-10-30_0154.fits', 'a_OI2018B-011_2018-10-30_0155.fits', 'a_OI2018B-011_2018-10-30_0156.fits']
# Creating image: final_OI2018B-011_2018-10-30_0007 (7 de 7)

# %% [markdown]
# # Getting final parameters

# %%
final_parameters_file = "final_parameters_18out30_120.csv"

if not exists(final_parameters_file):
    final_parameters = inspect(object_folder + "/final", ref_positions_file, final_parameters_file)
else:
    final_parameters = pd.read_csv(final_parameters_file)
# Out:
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# WARNING:astropy:The fit may be unsuccessful; check fit_info['message'] for more information.
# Getting parameters for file: final_OI2018B-011_2018-10-30_0001.fits (1 of 7)
# Getting parameters for file: final_OI2018B-011_2018-10-30_0002.fits (2 of 7)
# Getting parameters for file: final_OI2018B-011_2018-10-30_0003.fits (3 of 7)
# Getting parameters for file: final_OI2018B-011_2018-10-30_0004.fits (4 of 7)
# Getting parameters for file: final_OI2018B-011_2018-10-30_0005.fits (5 of 7)
# Getting parameters for file: final_OI2018B-011_2018-10-30_0006.fits (6 of 7)
# Getting parameters for file: final_OI2018B-011_2018-10-30_0007.fits (7 of 7)
#
# Finished getting parameters!

# %%
plt.plot("jd", "FWHM", data=parameters, c="silver")
plt.plot("jd", "FWHM", data=final_parameters)

# %% [markdown]
# Looks like everything is OK! Let's go on to the photometry !

# %% [markdown]
# # Photometry

# %% [markdown]
# Let's use the WDP to obtain the time series. It is structured in 2 steps:
#
# 1. Get catalog;
# 2. Assemble light curve.

# %%
# Lets get the catalog of sources

from wdpipe.photometry.aperture_phot import assemble_lightcurve, get_catalog


ref_img = object_folder + "/final/" + final_parameters.iloc[0].file
ref_pars = final_parameters.iloc[0]

cat, _ = get_catalog(ref_img, ref_pars.to_dict(), nsigma=5)

# %%
get_catalog?
# Out:
# Signature: get_catalog(ref_image, pars, nsigma=5)
# Docstring:
# Detect sources in image and create catalog of id, x_center and y_center of
# stars.
#
# Args:
#     ref_image -- String with path to reference image.
#     pars -- Pandas Series with image parameters.
#     nsigma -- Integer to multiply the sky sigma adding to the background
#               for threshold.
#
# Return:
#     positions -- 2D numpy array with catalog (Columns: 0 - ID; 1 - Xcenter; 2 - Ycenter)
#     sources -- Table containing the source properties
# File:      ~/MEGA/Projects/installing_wdpipe/WildDuckPipe/wdpipe/photometry/aperture_phot.py
# Type:      function

# %%
# Let's assemble the lightcurve

time_series_file = "time_series_18out30_120.csv"

if not exists(time_series_file):
    light_curve = assemble_lightcurve(object_folder + "/final",
                                      cat, final_parameters_file, 
                                      aperture_factors={'r': 1.5, 'r_in': 2.0, 'r_out': 3.0}
                                     )
    np.savetxt(time_series_file, light_curve, delimiter=",")
else:
    light_curve = np.loadtxt(time_series_file, delimiter=",")
# Out:
# Starting to assemble time series table of images on /home/jpsrocha/Documents/Data/OPD/r_18out30/reduced/M11/V/120/final
# /home/jpsrocha/MEGA/Projects/installing_wdpipe/wfc3_photometry/photometry_tools/background_median.py:96: RuntimeWarning: invalid value encountered in divide
#   values = cutout * mask.data / mask.data
# /home/jpsrocha/MEGA/Projects/installing_wdpipe/wfc3_photometry/photometry_tools/photometry_with_errors.py:126: RuntimeWarning: invalid value encountered in log10
#   mag = -2.5 * np.log10(flux)
# Doing photometry of final_OI2018B-011_2018-10-30_0002.fits ... (1 of 6)
# /home/jpsrocha/MEGA/Projects/installing_wdpipe/wfc3_photometry/photometry_tools/background_median.py:96: RuntimeWarning: invalid value encountered in divide
#   values = cutout * mask.data / mask.data
# /home/jpsrocha/MEGA/Projects/installing_wdpipe/wfc3_photometry/photometry_tools/photometry_with_errors.py:126: RuntimeWarning: invalid value encountered in log10
#   mag = -2.5 * np.log10(flux)
# Doing photometry of final_OI2018B-011_2018-10-30_0003.fits ... (2 of 6)
# /home/jpsrocha/MEGA/Projects/installing_wdpipe/wfc3_photometry/photometry_tools/background_median.py:96: RuntimeWarning: invalid value encountered in divide
#   values = cutout * mask.data / mask.data
# /home/jpsrocha/MEGA/Projects/installing_wdpipe/wfc3_photometry/photometry_tools/photometry_with_errors.py:126: RuntimeWarning: invalid value encountered in log10
#   mag = -2.5 * np.log10(flux)
# /home/jpsrocha/MEGA/Projects/installing_wdpipe/wfc3_photometry/photometry_tools/background_median.py:96: RuntimeWarning: invalid value encountered in divide
#   values = cutout * mask.data / mask.data
# Doing photometry of final_OI2018B-011_2018-10-30_0004.fits ... (3 of 6)
# /home/jpsrocha/MEGA/Projects/installing_wdpipe/wfc3_photometry/photometry_tools/photometry_with_errors.py:126: RuntimeWarning: invalid value encountered in log10
#   mag = -2.5 * np.log10(flux)
# /home/jpsrocha/MEGA/Projects/installing_wdpipe/wfc3_photometry/photometry_tools/background_median.py:96: RuntimeWarning: invalid value encountered in divide
#   values = cutout * mask.data / mask.data
# Doing photometry of final_OI2018B-011_2018-10-30_0005.fits ... (4 of 6)
# /home/jpsrocha/MEGA/Projects/installing_wdpipe/wfc3_photometry/photometry_tools/photometry_with_errors.py:126: RuntimeWarning: invalid value encountered in log10
#   mag = -2.5 * np.log10(flux)
# Doing photometry of final_OI2018B-011_2018-10-30_0006.fits ... (5 of 6)
# /home/jpsrocha/MEGA/Projects/installing_wdpipe/wfc3_photometry/photometry_tools/background_median.py:96: RuntimeWarning: invalid value encountered in divide
#   values = cutout * mask.data / mask.data
# /home/jpsrocha/MEGA/Projects/installing_wdpipe/wfc3_photometry/photometry_tools/photometry_with_errors.py:126: RuntimeWarning: invalid value encountered in log10
#   mag = -2.5 * np.log10(flux)
# Doing photometry of final_OI2018B-011_2018-10-30_0007.fits ... (6 of 6)
# /home/jpsrocha/MEGA/Projects/installing_wdpipe/wfc3_photometry/photometry_tools/background_median.py:96: RuntimeWarning: invalid value encountered in divide
#   values = cutout * mask.data / mask.data
# Finished Photometry.
# /home/jpsrocha/MEGA/Projects/installing_wdpipe/wfc3_photometry/photometry_tools/photometry_with_errors.py:126: RuntimeWarning: invalid value encountered in log10
#   mag = -2.5 * np.log10(flux)

# %%
light_curve.T
# Out:
# array([[ 1.00000000e+00,  2.00000000e+00,  3.00000000e+00, ...,
#          2.14600000e+03,  2.14700000e+03,  2.14800000e+03],
#        [ 5.66427803e+00,  2.04215906e+03,  7.93334576e+02, ...,
#          4.93378054e+00,  8.59257561e+01,  1.23969121e+03],
#        [ 4.80136396e+00,  5.30854041e+00,  5.83695079e+00, ...,
#          2.04138652e+03,  2.04202928e+03,  2.04243116e+03],
#        ...,
#        [-1.69576964e-02, -1.48389398e-02,  6.84601320e-03, ...,
#         -1.48449213e-02,  2.69661879e-02,  5.58148173e-03],
#        [            nan,             nan,  1.46165110e+01, ...,
#                     nan,  1.64357277e+01,  1.42099489e+01],
#        [-1.22176316e-02, -1.42037508e-02,  7.68077001e-03, ...,
#         -1.31210754e-02,  3.52882746e-02,  5.87315090e-03]])

# %%
fig, ax = plt.subplots()

means_1 = np.nanmean(light_curve[:, 3::2], axis=1)
stds_1 = np.nanstd(light_curve[:, 3::2], axis=1, ddof=1)

ax.scatter(means_1, stds_1, s=15, alpha=.5)
ax.set_xlim(11, 19)
ax.set_ylim(0, 0.2)
ax.set_xlabel("$V$")
ax.set_ylabel(f"$\sigma_V$")
ax.yaxis.grid()
ax.set_title(f"Série instrumental")
fig.tight_layout()
# Out:
# /tmp/ipykernel_339640/3013852932.py:3: RuntimeWarning: Mean of empty slice
#   means_1 = np.nanmean(light_curve[:, 3::2], axis=1)
# /home/jpsrocha/mambaforge/envs/wdpipe/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,

# %% [markdown]
# # Stellar Cluster Differential Photometry

# %%
from wdpipe.photometry.differential_phot import differential_photometry
ref_mags, ref_stars, diff_ts = differential_photometry(light_curve, n=5, viz=True)
# Out:
# /home/joaopedro/MEGA/Projects/active/Research_Wild-Duck-Pipeline_1-1-2019/res/WildDuckPipe/wdpipe/photometry/differential_phot.py:125: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig, [ax1, ax2] = plt.subplots(nrows=2)

y_b = 0.05


means = np.nanmean(diff_ts[:, 3:], axis=1)
stds = np.nanstd(diff_ts[:, 3:], axis=1, ddof=1)

means_1 = np.nanmean(light_curve[:, 3::2], axis=1)
stds_1 = np.nanstd(light_curve[:, 3::2], axis=1, ddof=1)

ax1.scatter(means_1, stds_1, s=15, alpha=.5)
ax1.set_xlim(11, 19)
ax1.set_ylim(0, y_b)
ax1.set_xlabel("$V$")
ax1.set_ylabel(f"$\sigma_V$")
ax1.yaxis.grid()
ax1.set_title(f"Série instrumental")


ax2.scatter(means, stds, s=15, alpha=.5)
ax2.set_xlim(-2, 6)
ax2.set_ylim(0, y_b)
ax2.set_xlabel("$V$")
ax2.set_ylabel(f"$\sigma_V$")
ax2.yaxis.grid()
ax2.set_title(f"Série diferencial")
fig.tight_layout()

# %%
ref_stars_file = "ref_stars_21mai03_30.csv"
differential_series_file = "diff_series_21mai03_30.csv"

np.savetxt(ref_stars_file, ref_stars, delimiter=",")
np.savetxt(differential_series_file, diff_ts, delimiter=",")

# %% [markdown]
# # Adding astrometry
#
# Let's add astrometry to the tables using a file with astrometric calibration done using the astrometry.net website.

# %%
from wdpipe.astrometry.add_astrometry import add_astrometry

# %%
add_astrometry(differential_series_file, "NGC6031_21mai03_30_astrometry.fits")
add_astrometry(ref_stars_file, "NGC6031_21mai03_30_astrometry.fits")
# Out:
# WARNING: FITSFixedWarning: EPOCH = '2000.0 ' / Epoca
# a floating-point value was expected. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59338.122790 from DATE-OBS'. [astropy.wcs.wcs]

# %%
references = np.loadtxt(ref_stars_file + ".wcs", delimiter=",")[:, :2]

# %%
np.savetxt("references.csv", references, delimiter=",")

# %%
for i in ref_stars[:, 3::2]:
    plt.plot(final_parameters.jd, i)
    
plt.plot(final_parameters.jd, ref_stars[:, 3::2].mean(axis=0), c="k", lw=5)
    
plt.title("Reference stars")
plt.ylabel("Instrumental Magnitude (V)")
plt.xlabel("Julian Date / [day]")
# Out:
# Text(0.5, 0, 'Julian Date / [day]')

# %%
plt.plot(final_parameters.jd, ref_stars[:, 3::2].mean(axis=0))
    
plt.title("Reference stars")
plt.ylabel("Instrumental Magnitude (V)")
plt.xlabel("Julian Date / [day]")
# Out:
# Text(0.5, 0, 'Julian Date / [day]')
